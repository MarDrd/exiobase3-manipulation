# %% [markdown]
# ## Regroupement des régions pour analyser l'évolution des impacts associés à la consommation finale.

# %%
#importation de la librairie
import pandas as pd

# %% [markdown]
# Création d'une DataFrame permettant de visualiser les pays appartenant aux régions créées pour mesurer l'évolution des impacts associés à la consommation finale.
#
# Pour obtenir des cartes de chaleur plus lisibles, nous avons décidé d'agréger certaines de nos régions initiales en réduisant le nombre de 49 régions définies initialement dans EXIOBASE3 à 16 régions.
#
# Cela a été possible en regroupant les pays de l'Union européenne pour former la région "Union européenne", en regroupant les pays de l'Asie-Pacifique (hors Chine, Inde, Indonésie et Japon que nous avons décidé de garder comme des régions à part entière), en regroupant les pays d'Europe qui ne font pas partie de l'Union européenne dans la région "Europe", en regroupant les pays du Moyen-Orient (hors la Turquie car ce pays est déjà comptabilisé dans la région "Europe"), en regroupant les pays d'Afrique dans la région "Afrique" (hors l'Égypte car ce pays déjà est comptabilisé dans la région "Moyen-Orient"), et en regroupant les pays de l'Amérique latine et des Caraïbes dans la région "Amérique Latine et Caraïbes" (hors le Brésil et le Mexique que nous conservons comme des régions à part entière).
#
# À part ces changements, nous gardons les régions "Chine", "États-Unis", "Inde", "Japon", "Indonésie", "Brésil", "Mexique", "Australie" et "Canada" telles qu'elles étaient définies dans la base de données EXIOBASE3.

# %%
#Création d'un dictionnaire avec 3 listes 'Région', 'Pays' et 'Continent'
Région_Descriptif = {
    'Région': ['Chine', 'États-Unis', 'Inde', 'Union européenne', 'Asie-Pacifique', 'Afrique', 'Moyen-Orient', 'Russie', 'Europe', 'Japon',
              'Amérique Latine et Caraïbes','Indonésie', 'Brésil', 'Mexique', 'Australie', 'Canada'],
    'Pays': ["République populaire de Chine",
            "États-Unis d'Amérique",
            "République de l'Inde",
            ["République d'Autriche", "Royaume de Belgique", "République de Bulgarie", "République tchèque", "République fédérale d'Allemagne",
            "Royaume de Danemark", "République d'Estonie", "Royaume d'Espagne", "République de Finlande", "République française", "République hellénique",
            "République de Croatie", "République de Hongrie", "Irlande", "République italienne", "République de Lituanie", "Grand-Duché de Luxembourg",
            "République de Lettonie", "République de Malte", "Royaume des Pays-Bas", "Royaume de Norvège", "République de Pologne", "République portugaise",
            "Roumanie", "Royaume de Suède", "République de Slovénie", "République slovaque"],
            ["République islamique d'Afghanistan", "Samoa américaines", "Antarctique", "République d'Arménie", "République d'Azerbaïdjan",
            "République populaire du Bangladesh", "Royaume du Bhoutan", "Île Bouvet", "Territoire britannique de l'océan Indien", "Nation de Brunei",
            "Demeure de la Paix", "Royaume du Cambodge", "République de Chine", "Île Christmas", "Territoire des Îles Cocos (Keeling)", "Îles Cook",
            "République des Fidji", "Polynésie française", "Géorgie", "Guam", "Territoire des îles Heard-et-MacDonald", "Hong Kong RAS", 
            "République du Kazakhstan", "République de Kiribati", "République de Corée", "République kirghize", "République démocratique populaire lao",
            "Macau RAS", "Malaisie", "République des Maldives", "République des Îles Marshall", "États fédérés de Micronésie", "Mongolie",
            "République de l'Union du Myanmar", "République de Nauru", "République fédérale démocratique du Népal", "Nouvelle-Calédonie", "Nouvelle-Zélande",
            "Niue", "Île Norfolk", "République populaire démocratique de Corée", "Îles Mariannes du Nord", "République islamique du Pakistan", "République de Palau",
            "État indépendant de Papouasie-Nouvelle-Guinée", "République des Philippines", "Pitcairn", "État indépendant des Samoa", "République de Singapour",
            "Îles Salomon", "Géorgie du Sud-et-les Îles Sandwich du Sud", "République socialiste démocratique de Sri Lanka", "République du Tadjikistan",
            "Royaume de Thaïlande", "République démocratique du Timor oriental", "Tokelau", "Royaume des Tonga", "Turkménistan", "Tuvalu",
            "Îles mineures éloignées des États-Unis", "République d'Ouzbékistan", "République de Vanuatu", "République socialiste du Viêt Nam", "Îles Wallis-et-Futuna"],
            ["République Démocratique Populaire d'Algérie", "République d'Angola", "République du Bénin", "République du Botswana", "Burkina Faso", "République du Burundi",
            "République du Cabo Verde", "République du Cameroun", "République Centrafricaine", "République du Tchad", "Union des Comores", "République du Congo",
            "République de Côte d'Ivoire", "République de Djibouti", "République Démocratique du Congo", "République de Guinée Équatoriale", "État d'Érythrée",
            "Royaume d'Eswatini", "République Fédérale Démocratique d'Éthiopie", "Territoire des Terres australes et antarctiques françaises", "République Gabonaise",
            "République de Gambie", "République du Ghana", "République de Guinée", "République de Guinée-Bissau", "République du Kenya", "Royaume du Lesotho",
            "République du Libéria", "État de Libye", "République de Madagascar", "République du Malawi", "République du Mali", "République Islamique de Mauritanie",
            "République de Maurice", "Mayotte", "Royaume du Maroc", "République du Mozambique", "République de Namibie", "République du Niger", "République Fédérale du Nigeria",
            "Réunion", "République du Rwanda", "République Démocratique de Sao Tomé et Príncipe", "République du Sénégal", "République des Seychelles", "République de Sierra Leone",
            "République Fédérale de Somalie", "République d'Afrique du Sud", "République du Soudan du Sud", "Sainte-Hélène, Ascension et Tristan da Cunha", "République du Soudan",
            "République Unie de Tanzanie", "République Togolaise", "République de Tunisie", "République d'Ouganda", "Sahara Occidental", "République de Zambie",
            "République du Zimbabwe"],
            ["Royaume de Bahreïn", "République de Chypre", "République arabe d'Égypte", "République islamique d'Iran", "République d'Irak", "État d'Israël",
            "Royaume hachémite de Jordanie", "État du Koweït", "République libanaise", "Sultanat d'Oman", "État de Palestine", "État du Qatar", "Royaume d'Arabie saoudite",
            "République arabe syrienne", "Émirats arabes unis","République du Yémen"],
            "Russie", 
            ["Îles Åland", "République d'Albanie", "Principauté d'Andorre", "République de Biélorussie", "Bosnie-Herzégovine", "Îles Féroé", "Gibraltar", "Guernesey",
            "République d'Islande", "Île de Man", "Jersey", "République du Kosovo", "Principauté de Liechtenstein", "République de Macédoine du Nord", "République de Moldavie", 
            "Principauté de Monaco", "Monténégro", "République de Saint-Marin", "République de Serbie", "Confédération suisse", "Îles Svalbard et Jan Mayen", "République de Turquie", 
            "Ukraine", "Royaume-Uni de Grande-Bretagne et d'Irlande du Nord", "État de la Cité du Vatican"],
            "Japon",
            ["Anguilla", "Antigua-et-Barbuda", "République argentine", "Aruba", "Commonwealth des Bahamas", "Barbade", "Belize", "Bermudes", "État plurinational de Bolivie",
            "Bonaire", "Saint-Eustache et Saba", "Îles Vierges britanniques", "Îles Caïmans", "République du Chili", "République de Colombie", "République du Costa Rica",
            "République de Cuba","Pays de Curaçao", "Commonwealth de la Dominique", "République dominicaine", "République de l'Équateur", "République du Salvador",
            "Îles Falkland (Malvinas)", "Guyane", "Groenland", "Grenade", "Guadeloupe", "République du Guatemala", "République coopérative du Guyana", "République d'Haïti",
            "République du Honduras", "Jamaïque", "Martinique", "Montserrat","République du Nicaragua", "République du Panama", "République du Paraguay", "République du Pérou",
            "Porto Rico", "Saint-Martin (partie française)", "Sint Maarten (partie néerlandaise)", "Collectivité territoriale de Saint-Barthélemy", "Saint-Christophe-et-Niévès",
            "Sainte-Lucie", "Saint-Pierre-et-Miquelon", "Saint-Vincent-et-les-Grenadines", "République du Suriname", "République de Trinité-et-Tobago", "Îles Turques-et-Caïques",
            "Îles Vierges des États-Unis", "République orientale de l'Uruguay", "République bolivarienne du Venezuela"],
            "République d'Indonésie",
            "République fédérative du Brésil",
            "États-Unis mexicains",
            "Commonwealth d'Australie",
            "Canada"],
    'Continent': ["Asie",
                 "Amérique",
                 "Asie", 
                ["Europe", "Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe",
                "Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe","Europe"],
                ["Asie", "Océanie", "Antarctique", "Asie", "Asie", "Asie", "Asie", "Antarctique", "Afrique", "Asie", "Asie", "Asie", "Asie", "Asie", "Océanie", "Océanie",
                "Océanie", "Asie", "Océanie", "Antarctique", "Asie", "Asie", "Océanie", "Asie", "Asie", "Asie", "Asie", "Asie", "Asie", "Océanie", "Océanie", "Asie", "Asie",
                "Océanie", "Asie", "Océanie", "Océanie", "Océanie", "Océanie", "Asie", "Océanie", "Asie", "Océanie", "Océanie", "Asie", "Océanie", "Océanie", "Asie", "Océanie",
                "Antarctique", "Asie", "Asie", "Asie", "Asie", "Océanie", "Océanie", "Asie", "Océanie", "Océanie", "Asie", "Océanie", "Asie", "Océanie"],
                ["Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", 
                "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", 
                "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", 
                "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique", "Afrique"],
                ["Asie", "Europe", "Afrique", "Asie", "Asie", "Asie", "Asie", "Asie", "Asie", "Asie", "Asie", "Asie", "Asie", "Asie", "Asie", "Asie"],
                "Europe",
                ["Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe", "Europe","Europe", "Europe", "Europe" ],
                "Asie",
                ["Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique",
                "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique",
                "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique",
                "Amérique", "Amérique", "Amérique","Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique", "Amérique"],
                "Asie",
                "Amérique",
                "Amérique",
                "Océanie",
                "Amérique"
                ]
}

#Conversion du dictionnaire en DataFrame
index = range(len(Région_Descriptif['Région']))
df = pd.DataFrame(Région_Descriptif, index=index)

#Enregistrer DataFrame en format csv
df.to_csv('Régions_Agrégées.csv')

#Permet d'afficher le contenu entier de la DataFrame
pd.set_option('display.max_colwidth', None)

#Afficher la DataFrame
df
# Out:
#                          Région  \
# 0                         Chine
# 1                    États-Unis
# 2                          Inde
# 3              Union européenne
# 4                Asie-Pacifique
# 5                       Afrique
# 6                  Moyen-Orient
# 7                        Russie
# 8                        Europe
# 9                         Japon
# 10  Amérique Latine et Caraïbes
# 11                    Indonésie
# 12                       Brésil
# 13                      Mexique
# 14                    Australie
# 15                       Canada
#
# ...
